# %%
import pandas as pd
import matplotlib.pyplot as mp
import numpy as np

with open('histogramm.txt') as f:
        lines = f.readlines()
        x=[line.split()[0] for line in lines]

# %%
def plot(N):
    x_t = x[N].split(',')
    x_t = x_t[:-1]
    x_t = list(map(float, x_t))
    x_z = np.array(x_t)
    y = [i for i in range(len(x_t))]
    y_t = np.array(y)
    mp.plot(y_t,x_z)

# %%
print(x[0])
# Out:
# 7,5,10,8,5,6,2,0,3,7,6,3,4,4,4,7,5,3,6,4,1,6,5,7,7,5,8,6,4,5,6,3,2,3,5,8,5,5,7,3,1,3,4,7,8,4,5,4,6,8,6,7,9,5,0,7,9,7,7,4,4,7,6,3,4,9,8,4,3,3,3,3,4,5,5,2,1,4,8,7,4,4,6,4,4,11,11,4,4,5,4,3,3,4,6,8,4,2,6,10,6,

# %%
plot(0)

# %%
plot(1)

# %%
plot(2)

# %%
plot(3)

# %%
plot(4)

# %%
plot(5)

# %%
plot(6)

# %%
plot(7)

# %%
plot(8)
