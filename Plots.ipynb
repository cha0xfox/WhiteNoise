# %%
import pandas as pd
import matplotlib.pyplot as mp
import numpy as np

with open('histogramm.txt') as f:
        lines = f.readlines()
        x=[line.split()[0] for line in lines]

# %%
def plot(N):
    x_t = x[N].split(',')
    x_t = x_t[:-1]
    x_t = list(map(float, x_t))
    x_z = np.array(x_t)
    y = [i for i in range(len(x_t))]
    y_t = np.array(y)
    mp.plot(y_t,x_z)

# %%
plot(0)

# %%
plot(1)

# %%
plot(2)

# %%
plot(3)

# %%
plot(4)

# %%
plot(5)

# %%
plot(6)

# %%
plot(7)

# %%
plot(8)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-564-2b0de402f9b4> in <module>
# ----> 1 plot(8)
#
# <ipython-input-555-a7f419d6ad7f> in plot(N)
#       1 def plot(N):
# ----> 2     x_t = x[N].split(',')
#       3     x_t = x_t[:-1]
#       4     x_t = list(map(float, x_t))
#       5     x_z = np.array(x_t)
#
# IndexError: list index out of range
